# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False) 
# setting the style of the notebook to be monokai theme  
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
icecream_df = pd.read_csv('IceCreamData.csv')

# %%
icecream_df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
icecream_df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
icecream_df.tail(10)
# Out:
#      Temperature     Revenue
# 490    23.824922  584.399945
# 491    34.472169  809.352519
# 492    23.056214  552.819351
# 493    14.931506  377.430928
# 494    25.112066  571.434257
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
icecream_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
icecream_df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 [OPTIONAL]:**
# - **Calculate the average and maximum temperature and revenue using an alternative method**

# %%
max_ = icecream_df.Revenue.max()
mean_ = icecream_df.Revenue.mean()
print("Max: ", max_)
print("Mean: ", mean_)
# Out:
# Max:  1000.0
# Mean:  521.57077669154

# %% [markdown]
# # TASK #3: PERFORM DATA VISUALIZATION

# %%
plt.figure(figsize=(13, 7))
sns.scatterplot(data=icecream_df, y='Revenue', x='Temperature')
# Out:
# <Axes: xlabel='Temperature', ylabel='Revenue'>

# %%
plt.figure(figsize=(13, 7))
sns.regplot(data=icecream_df, y='Revenue', x='Temperature')
# Out:
# <Axes: xlabel='Temperature', ylabel='Revenue'>

# %% [markdown]
# # TASK #4: CREATE TESTING AND TRAINING DATASET

# %%
icecream_df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
X = icecream_df['Temperature']
y = icecream_df['Revenue']

# %%
X = np.array(X)
y = np.array(y)

# %%
# reshaping the array from (500,) to (500, 1)
X = X.reshape(-1,1)
print(X.shape)

# reshaping the array from (500,) to (500, 1)
y = y.reshape(-1,1)
print(y.shape)
# Out:
# (500, 1)
# (500, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (400, 1)

# %%
y_train.shape
# Out:
# (400, 1)

# %%
X_test.shape
# Out:
# (100, 1)

# %%
y_test.shape
# Out:
# (100, 1)

# %% [markdown]
# # TASK #5: UNDERSTAND THEORY BEHIND SIMPLE LINER REGRESSION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #6: TRAIN A SIMPLE LINEAR REGRESSION MODEL IN SCIKIT LEARN

# %%
from sklearn.linear_model import LinearRegression
SimpleLinearRegression = LinearRegression(fit_intercept=True)
SimpleLinearRegression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coeff(m)', SimpleLinearRegression.coef_)
print('Linear Model Coeff(b)', SimpleLinearRegression.intercept_)
# Out:
# Linear Model Coeff(m) [[21.42070006]]
# Linear Model Coeff(b) [45.54574431]

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Set the fit_intercept attribute to False and retrain the model. What do you notice? comment on the result.**

# %%
OptionalLinearRegression = LinearRegression(fit_intercept=False)
OptionalLinearRegression.fit(X_train, y_train)
print('Linear Model Coeff(m)', OptionalLinearRegression.coef_)
print('Linear Model Coeff(b)', OptionalLinearRegression.intercept_)
# Out:
# Linear Model Coeff(m) [[23.22173468]]
# Linear Model Coeff(b) 0.0

# %% [markdown]
# # TASK #7: EVALUATE TRAINED SIMPLE LINEAR REGRESSION MODEL IN SCIKIT LEARN

# %%
plt.scatter(X_train, y_train, color='gray')
plt.plot(X_train, SimpleLinearRegression.predict(X_train), color='red')
plt.ylabel("Revenue [$]")
plt.xlabel("Temperature")
# Out:
# Text(0.5, 0, 'Temperature')

# %%
accuracy_LinearRegression = SimpleLinearRegression.score(X_test, y_test)
accuracy_LinearRegression
# Out:
# 0.9811402042300993

# %%
plt.scatter(X_test, y_test, color='gray')
plt.plot(X_test, SimpleLinearRegression.predict(X_test), color='red')
plt.ylabel("Revenue [$]")
plt.xlabel("Temperature")
# Out:
# Text(0.5, 0, 'Temperature')

# %%
# Use the trained model to generate predictions

Temp = np.array([20])
Temp = Temp.reshape(-1,1)

Revenue = SimpleLinearRegression.predict(Temp)
print('Revenue Predictions =', Revenue)
# Out:
# Revenue Predictions = [[473.95974551]]
